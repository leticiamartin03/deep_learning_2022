# %% [markdown]
# # MODEL COMPARISION WITH AMAZON DATA

# %%
#Import libraries

import numpy as np
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import random
import math
import string
import pandas as pd 
from google.colab import drive
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import seaborn as sns 
from sklearn.metrics import mean_squared_error

# %%
drive.mount('/content/drive')
# !ls '/content/drive/My Drive/DeepLearning_2022/FinalProject/Data/'
path = '/content/drive/My Drive/DeepLearning_2022/FinalProject/Data/'
path_results = '/content/drive/My Drive/DeepLearning_2022/FinalProject/Results/'
# Out:
# Mounted at /content/drive
# AMAZON.csv  DownloadData.ipynb	GOOGLE.csv

# %%
df_mlp = pd.read_csv(path_results+'result_MLP_AMZN.csv')
df_gru = pd.read_csv(path_results+'result_GRU_AMZN.csv')
df_lstm = pd.read_csv(path_results+'result_LSTM_AMZN.csv')

# %%
df_mlp = df_mlp.rename(columns = {'0': 'train_mlp', '1':'test_mlp', '2':'actual'})
df_gru = df_gru.rename(columns = {'0': 'train_gru', '1':'test_gru', '2':'actual'})
df_lstm = df_lstm.rename(columns = {'0': 'train_lstm', '1':'test_lstm', '2':'actual'})

# %%
results_final = df_mlp
results_final['train_gru'] = df_gru['train_gru']
results_final['test_gru'] = df_gru['test_gru']
results_final['train_lstm'] = df_lstm['train_lstm']
results_final['test_lstm'] = df_lstm['test_lstm']
results_final = results_final[['Date','actual','train_mlp','train_gru','train_lstm', 'test_mlp','test_gru', 'test_lstm']]
results_final.head()
# Out:
#          Date  actual  train_mlp  train_gru  train_lstm  test_mlp  test_gru  \
# 0  2010-01-04  6.6950        NaN        NaN         NaN       NaN       NaN
# 1  2010-01-05  6.7345        NaN        NaN         NaN       NaN       NaN
# 2  2010-01-06  6.6125        NaN        NaN         NaN       NaN       NaN
# 3  2010-01-07  6.5000        NaN        NaN         NaN       NaN       NaN
# 4  2010-01-08  6.6760        NaN        NaN         NaN       NaN       NaN
#
#    test_lstm
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
results_final.index
results_final.iloc[:,1]
# Out:
# 0        6.695000
# 1        6.734500
# 2        6.612500
# 3        6.500000
# 4        6.676000
#           ...
# 2511    89.460503
# 2512    93.438499
# 2513    93.489998
# 2514    92.344498
# 2515    92.391998
# Name: actual, Length: 2516, dtype: float64

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=results_final.index, y=results_final.iloc[:,1],
                    mode='lines',
                    name='Actual Value')))
fig.add_trace(go.Scatter(go.Scatter(x=results_final.index, y=results_final.iloc[:,2],
                    mode='lines',
                    name='Train prediction_MLP')))
fig.add_trace(go.Scatter(go.Scatter(x=results_final.index, y=results_final.iloc[:,3],
                    mode='lines',
                    name='Train prediction_GRU')))
fig.add_trace(go.Scatter(go.Scatter(x=results_final.index, y=results_final.iloc[:,4],
                    mode='lines',
                    name='Train prediction_LSTM')))
fig.add_trace(go.Scatter(x=results_final.index, y=results_final.iloc[:,5],
                    mode='lines',
                    name='Test prediction_MLP'))
fig.add_trace(go.Scatter(x=results_final.index, y=results_final.iloc[:,6],
                    mode='lines',
                    name='Test prediction_GRU'))
fig.add_trace(go.Scatter(x=results_final.index, y=results_final.iloc[:,7],
                    mode='lines',
                    name='Test prediction_LSTM'))
fig.update_layout(
    xaxis=dict(
        title_text='Days',
        titlefont=dict(
            family='Rockwell',
            size=12,
            color='black',
        ),
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='black',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Rockwell',
            size=12,
            color='black',
        ),
    ),
    yaxis=dict(
        title_text='Close (USD)',
        titlefont=dict(
            family='Rockwell',
            size=12,
            color='black',
        ),
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='black',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Rockwell',
            size=12,
            color='black',
        ),
    ),
    showlegend=True,
    template = 'plotly_white'

)

annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='MODEL COMPARISONS WITH AMAZON DATA',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='black'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
